# %%
# import google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# replace <PATH-TO-YOUR-ZIP> with the path on your google drive
# Example: ! unzip /content/drive/MyDrive/M214A\ Winter\ 2026/Project/M214_project_data.zip -d /content/
! unzip /content/drive/MyDrive/M214_project_data.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/M214_project_data.zip
#    creating: /content/M214_project_data/
#    creating: /content/M214_project_data/test_clean/
#   inflating: /content/M214_project_data/test_clean/7_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/6_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/4_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/1_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/8_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/2_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/4_george_0.wav
#   inflating: /content/M214_project_data/test_clean/4_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/6_george_3.wav
#   inflating: /content/M214_project_data/test_clean/7_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/3_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/3_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/1_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/5_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/0_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/4_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/4_george_4.wav
#   inflating: /content/M214_project_data/test_clean/2_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/1_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/2_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/0_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/4_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/0_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/2_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/4_george_2.wav
#   inflating: /content/M214_project_data/test_clean/0_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/1_george_3.wav
#   inflating: /content/M214_project_data/test_clean/8_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/3_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/0_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/9_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/7_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/5_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/5_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/1_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/6_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/7_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/4_george_3.wav
#   inflating: /content/M214_project_data/test_clean/1_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/9_george_2.wav
#   inflating: /content/M214_project_data/test_clean/4_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/9_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/7_george_1.wav
#   inflating: /content/M214_project_data/test_clean/7_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/9_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/4_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/0_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/9_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/6_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/7_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/6_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/2_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/1_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/3_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/7_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/0_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/3_george_3.wav
#   inflating: /content/M214_project_data/test_clean/5_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/7_george_3.wav
#   inflating: /content/M214_project_data/test_clean/6_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/7_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/2_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/1_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/1_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/3_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/0_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/1_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/1_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/3_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/5_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/9_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/0_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/9_george_3.wav
#   inflating: /content/M214_project_data/test_clean/2_george_1.wav
#   inflating: /content/M214_project_data/test_clean/3_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/8_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/4_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/4_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/0_george_2.wav
#   inflating: /content/M214_project_data/test_clean/6_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/5_george_1.wav
#   inflating: /content/M214_project_data/test_clean/9_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/3_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/0_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/3_george_4.wav
#   inflating: /content/M214_project_data/test_clean/2_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/8_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/5_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/0_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/8_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/6_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/3_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/2_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/4_george_1.wav
#   inflating: /content/M214_project_data/test_clean/4_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/0_george_4.wav
#   inflating: /content/M214_project_data/test_clean/4_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/0_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/9_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/6_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/6_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/0_george_1.wav
#   inflating: /content/M214_project_data/test_clean/2_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/9_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/0_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/3_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/4_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/7_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/6_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/3_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/2_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/1_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/2_george_0.wav
#   inflating: /content/M214_project_data/test_clean/9_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/3_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/8_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/9_george_0.wav
#   inflating: /content/M214_project_data/test_clean/9_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/3_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/2_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/7_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/0_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/5_george_4.wav
#   inflating: /content/M214_project_data/test_clean/3_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/6_george_4.wav
#   inflating: /content/M214_project_data/test_clean/3_george_0.wav
#   inflating: /content/M214_project_data/test_clean/3_george_2.wav
#   inflating: /content/M214_project_data/test_clean/9_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/1_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/0_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/9_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/9_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/7_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/4_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/4_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/1_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/1_george_2.wav
#   inflating: /content/M214_project_data/test_clean/1_george_0.wav
#   inflating: /content/M214_project_data/test_clean/0_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/1_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/6_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/9_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/7_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/2_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/8_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/3_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/2_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/8_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/6_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/8_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/5_george_0.wav
#   inflating: /content/M214_project_data/test_clean/2_george_2.wav
#   inflating: /content/M214_project_data/test_clean/0_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/5_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/9_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/0_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/7_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/7_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/3_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/0_george_0.wav
#   inflating: /content/M214_project_data/test_clean/5_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/4_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/4_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/6_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/0_george_3.wav
#   inflating: /content/M214_project_data/test_clean/5_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/6_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/4_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/1_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/7_george_4.wav
#   inflating: /content/M214_project_data/test_clean/8_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/9_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/7_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/8_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/5_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/3_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/2_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/3_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/3_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/4_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/1_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/5_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/9_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/5_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/9_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/3_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/4_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/0_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/5_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/8_george_4.wav
#   inflating: /content/M214_project_data/test_clean/5_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/9_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/4_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/2_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/1_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/8_nicolas_4.wav
#   inflating: /content/M214_project_data/test_clean/5_george_3.wav
#   inflating: /content/M214_project_data/test_clean/8_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/4_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/8_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/8_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/5_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/2_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/2_george_4.wav
#   inflating: /content/M214_project_data/test_clean/9_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/6_george_1.wav
#   inflating: /content/M214_project_data/test_clean/7_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/2_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/1_george_1.wav
#   inflating: /content/M214_project_data/test_clean/5_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/0_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/4_theo_2.wav
#   inflating: /content/M214_project_data/test_clean/7_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/3_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/9_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/7_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/8_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/2_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/8_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/9_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/6_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/1_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/5_jackson_1.wav
#   inflating: /content/M214_project_data/test_clean/1_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/1_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/5_theo_0.wav
#   inflating: /content/M214_project_data/test_clean/3_george_1.wav
#   inflating: /content/M214_project_data/test_clean/1_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/3_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/7_george_2.wav
#   inflating: /content/M214_project_data/test_clean/9_george_4.wav
#   inflating: /content/M214_project_data/test_clean/8_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/6_george_0.wav
#   inflating: /content/M214_project_data/test_clean/7_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/0_lucas_3.wav
#   inflating: /content/M214_project_data/test_clean/0_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/2_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/0_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/5_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/5_george_2.wav
#   inflating: /content/M214_project_data/test_clean/9_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/8_george_1.wav
#   inflating: /content/M214_project_data/test_clean/7_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/8_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/8_george_3.wav
#   inflating: /content/M214_project_data/test_clean/9_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/5_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/6_lucas_4.wav
#   inflating: /content/M214_project_data/test_clean/0_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/7_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/4_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/3_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/8_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/6_jackson_3.wav
#   inflating: /content/M214_project_data/test_clean/4_lucas_1.wav
#   inflating: /content/M214_project_data/test_clean/1_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/5_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/6_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/7_jackson_4.wav
#   inflating: /content/M214_project_data/test_clean/3_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/6_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/1_lucas_0.wav
#   inflating: /content/M214_project_data/test_clean/5_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/8_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/8_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/6_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/2_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/2_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/0_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/7_george_0.wav
#   inflating: /content/M214_project_data/test_clean/7_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/4_yweweler_1.wav
#   inflating: /content/M214_project_data/test_clean/4_nicolas_2.wav
#   inflating: /content/M214_project_data/test_clean/9_george_1.wav
#   inflating: /content/M214_project_data/test_clean/5_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/6_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/2_yweweler_0.wav
#   inflating: /content/M214_project_data/test_clean/6_nicolas_3.wav
#   inflating: /content/M214_project_data/test_clean/6_yweweler_3.wav
#   inflating: /content/M214_project_data/test_clean/8_george_2.wav
#   inflating: /content/M214_project_data/test_clean/3_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/5_nicolas_0.wav
#   inflating: /content/M214_project_data/test_clean/8_yweweler_2.wav
#   inflating: /content/M214_project_data/test_clean/7_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/1_george_4.wav
#   inflating: /content/M214_project_data/test_clean/8_george_0.wav
#   inflating: /content/M214_project_data/test_clean/8_jackson_0.wav
#   inflating: /content/M214_project_data/test_clean/6_george_2.wav
#   inflating: /content/M214_project_data/test_clean/5_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/1_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/1_theo_3.wav
#   inflating: /content/M214_project_data/test_clean/2_george_3.wav
#   inflating: /content/M214_project_data/test_clean/8_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/2_jackson_2.wav
#   inflating: /content/M214_project_data/test_clean/6_theo_4.wav
#   inflating: /content/M214_project_data/test_clean/6_nicolas_1.wav
#   inflating: /content/M214_project_data/test_clean/9_theo_1.wav
#   inflating: /content/M214_project_data/test_clean/2_yweweler_4.wav
#   inflating: /content/M214_project_data/test_clean/2_lucas_2.wav
#   inflating: /content/M214_project_data/test_clean/7_jackson_1.wav
#    creating: /content/M214_project_data/train_clean/
#   inflating: /content/M214_project_data/train_clean/7_yweweler_41.wav
#   inflating: /content/M214_project_data/train_clean/5_jackson_10.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_31.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_29.wav
#   inflating: /content/M214_project_data/train_clean/2_theo_41.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_31.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_37.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_28.wav
#   inflating: /content/M214_project_data/train_clean/6_jackson_24.wav
#   inflating: /content/M214_project_data/train_clean/9_lucas_42.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_6.wav
#   inflating: /content/M214_project_data/train_clean/9_nicolas_19.wav
#   inflating: /content/M214_project_data/train_clean/2_theo_39.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_36.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_12.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_38.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_47.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_36.wav
#   inflating: /content/M214_project_data/train_clean/2_nicolas_44.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_44.wav
#   inflating: /content/M214_project_data/train_clean/3_lucas_40.wav
#   inflating: /content/M214_project_data/train_clean/1_theo_10.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_9.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_41.wav
#   inflating: /content/M214_project_data/train_clean/8_yweweler_44.wav
#   inflating: /content/M214_project_data/train_clean/1_theo_25.wav
#   inflating: /content/M214_project_data/train_clean/1_theo_24.wav
#   inflating: /content/M214_project_data/train_clean/0_yweweler_13.wav
#   inflating: /content/M214_project_data/train_clean/7_nicolas_47.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_16.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_16.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_25.wav
#   inflating: /content/M214_project_data/train_clean/1_yweweler_36.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_15.wav
#   inflating: /content/M214_project_data/train_clean/3_george_20.wav
#   inflating: /content/M214_project_data/train_clean/6_george_5.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_48.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_31.wav
#   inflating: /content/M214_project_data/train_clean/2_george_24.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_6.wav
#   inflating: /content/M214_project_data/train_clean/3_yweweler_7.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_25.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_48.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_24.wav
#   inflating: /content/M214_project_data/train_clean/5_lucas_5.wav
#   inflating: /content/M214_project_data/train_clean/3_george_31.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_7.wav
#   inflating: /content/M214_project_data/train_clean/1_george_10.wav
#   inflating: /content/M214_project_data/train_clean/8_jackson_23.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_9.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_8.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_43.wav
#   inflating: /content/M214_project_data/train_clean/2_george_18.wav
#   inflating: /content/M214_project_data/train_clean/8_george_39.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_17.wav
#   inflating: /content/M214_project_data/train_clean/9_george_11.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_45.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_18.wav
#   inflating: /content/M214_project_data/train_clean/0_yweweler_21.wav
#   inflating: /content/M214_project_data/train_clean/5_jackson_41.wav
#   inflating: /content/M214_project_data/train_clean/6_nicolas_11.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_27.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_49.wav
#   inflating: /content/M214_project_data/train_clean/5_theo_13.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_26.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_25.wav
#   inflating: /content/M214_project_data/train_clean/4_george_24.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_9.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_10.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_31.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_33.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_21.wav
#   inflating: /content/M214_project_data/train_clean/5_lucas_27.wav
#   inflating: /content/M214_project_data/train_clean/9_nicolas_32.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_39.wav
#   inflating: /content/M214_project_data/train_clean/4_nicolas_36.wav
#   inflating: /content/M214_project_data/train_clean/5_george_43.wav
#   inflating: /content/M214_project_data/train_clean/6_jackson_5.wav
#   inflating: /content/M214_project_data/train_clean/9_george_14.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_27.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_11.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_25.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_16.wav
#   inflating: /content/M214_project_data/train_clean/5_yweweler_28.wav
#   inflating: /content/M214_project_data/train_clean/8_george_30.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_20.wav
#   inflating: /content/M214_project_data/train_clean/9_george_6.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_18.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_38.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_15.wav
#   inflating: /content/M214_project_data/train_clean/8_yweweler_41.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_25.wav
#   inflating: /content/M214_project_data/train_clean/9_george_16.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_42.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_15.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_8.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_41.wav
#   inflating: /content/M214_project_data/train_clean/1_george_13.wav
#   inflating: /content/M214_project_data/train_clean/2_nicolas_47.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_11.wav
#   inflating: /content/M214_project_data/train_clean/4_nicolas_5.wav
#   inflating: /content/M214_project_data/train_clean/5_jackson_38.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_8.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_36.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_26.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_7.wav
#   inflating: /content/M214_project_data/train_clean/2_theo_43.wav
#   inflating: /content/M214_project_data/train_clean/6_george_36.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_40.wav
#   inflating: /content/M214_project_data/train_clean/6_george_13.wav
#   inflating: /content/M214_project_data/train_clean/9_george_25.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_11.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_26.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_14.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_22.wav
#   inflating: /content/M214_project_data/train_clean/3_yweweler_6.wav
#   inflating: /content/M214_project_data/train_clean/5_jackson_18.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_11.wav
#   inflating: /content/M214_project_data/train_clean/7_nicolas_9.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_33.wav
#   inflating: /content/M214_project_data/train_clean/5_nicolas_41.wav
#   inflating: /content/M214_project_data/train_clean/3_george_8.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_10.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_25.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_6.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_34.wav
#   inflating: /content/M214_project_data/train_clean/3_lucas_15.wav
#   inflating: /content/M214_project_data/train_clean/2_theo_9.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_40.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_44.wav
#   inflating: /content/M214_project_data/train_clean/7_nicolas_27.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_28.wav
#   inflating: /content/M214_project_data/train_clean/9_george_47.wav
#   inflating: /content/M214_project_data/train_clean/6_lucas_12.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_47.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_47.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_13.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_23.wav
#   inflating: /content/M214_project_data/train_clean/4_george_31.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_6.wav
#   inflating: /content/M214_project_data/train_clean/5_george_6.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_35.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_5.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_48.wav
#   inflating: /content/M214_project_data/train_clean/5_yweweler_33.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_41.wav
#   inflating: /content/M214_project_data/train_clean/6_lucas_6.wav
#   inflating: /content/M214_project_data/train_clean/7_nicolas_21.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_40.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_31.wav
#   inflating: /content/M214_project_data/train_clean/8_jackson_46.wav
#   inflating: /content/M214_project_data/train_clean/1_yweweler_24.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_35.wav
#   inflating: /content/M214_project_data/train_clean/7_jackson_22.wav
#   inflating: /content/M214_project_data/train_clean/4_nicolas_24.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_23.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_5.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_38.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_41.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_10.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_41.wav
#   inflating: /content/M214_project_data/train_clean/7_george_14.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_17.wav
#   inflating: /content/M214_project_data/train_clean/8_jackson_45.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_35.wav
#   inflating: /content/M214_project_data/train_clean/5_theo_10.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_49.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_33.wav
#   inflating: /content/M214_project_data/train_clean/7_george_19.wav
#   inflating: /content/M214_project_data/train_clean/0_george_36.wav
#   inflating: /content/M214_project_data/train_clean/6_jackson_43.wav
#   inflating: /content/M214_project_data/train_clean/1_theo_45.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_7.wav
#   inflating: /content/M214_project_data/train_clean/8_jackson_41.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_13.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_46.wav
#   inflating: /content/M214_project_data/train_clean/6_jackson_46.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_31.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_28.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_6.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_35.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_39.wav
#   inflating: /content/M214_project_data/train_clean/1_yweweler_19.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_21.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_16.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_33.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_31.wav
#   inflating: /content/M214_project_data/train_clean/3_lucas_27.wav
#   inflating: /content/M214_project_data/train_clean/2_theo_36.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_9.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_32.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_29.wav
#   inflating: /content/M214_project_data/train_clean/6_george_15.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_47.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_6.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_5.wav
#   inflating: /content/M214_project_data/train_clean/1_yweweler_9.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_45.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_18.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_13.wav
#   inflating: /content/M214_project_data/train_clean/5_nicolas_24.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_28.wav
#   inflating: /content/M214_project_data/train_clean/3_george_17.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_21.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_20.wav
#   inflating: /content/M214_project_data/train_clean/5_lucas_49.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_47.wav
#   inflating: /content/M214_project_data/train_clean/3_george_32.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_46.wav
#   inflating: /content/M214_project_data/train_clean/7_nicolas_16.wav
#   inflating: /content/M214_project_data/train_clean/2_george_15.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_7.wav
#   inflating: /content/M214_project_data/train_clean/8_george_34.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_27.wav
#   inflating: /content/M214_project_data/train_clean/0_george_28.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_17.wav
#   inflating: /content/M214_project_data/train_clean/0_theo_18.wav
#   inflating: /content/M214_project_data/train_clean/4_george_29.wav
#   inflating: /content/M214_project_data/train_clean/9_jackson_12.wav
#   inflating: /content/M214_project_data/train_clean/7_george_25.wav
#   inflating: /content/M214_project_data/train_clean/6_yweweler_20.wav
#   inflating: /content/M214_project_data/train_clean/3_george_28.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_34.wav
#   inflating: /content/M214_project_data/train_clean/3_george_11.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_27.wav
#   inflating: /content/M214_project_data/train_clean/8_lucas_7.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_5.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_14.wav
#   inflating: /content/M214_project_data/train_clean/5_theo_11.wav
#   inflating: /content/M214_project_data/train_clean/6_nicolas_27.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_32.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_12.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_27.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_15.wav
#   inflating: /content/M214_project_data/train_clean/8_george_25.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_34.wav
#   inflating: /content/M214_project_data/train_clean/6_george_22.wav
#   inflating: /content/M214_project_data/train_clean/3_lucas_23.wav
#   inflating: /content/M214_project_data/train_clean/9_george_15.wav
#   inflating: /content/M214_project_data/train_clean/5_jackson_21.wav
#   inflating: /content/M214_project_data/train_clean/5_theo_43.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_39.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_14.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_5.wav
#   inflating: /content/M214_project_data/train_clean/5_nicolas_15.wav
#   inflating: /content/M214_project_data/train_clean/0_george_17.wav
#   inflating: /content/M214_project_data/train_clean/5_yweweler_7.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_17.wav
#   inflating: /content/M214_project_data/train_clean/5_jackson_22.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_43.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_43.wav
#   inflating: /content/M214_project_data/train_clean/5_yweweler_10.wav
#   inflating: /content/M214_project_data/train_clean/4_george_21.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_46.wav
#   inflating: /content/M214_project_data/train_clean/3_george_35.wav
#   inflating: /content/M214_project_data/train_clean/8_jackson_27.wav
#   inflating: /content/M214_project_data/train_clean/8_george_14.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_28.wav
#   inflating: /content/M214_project_data/train_clean/3_george_24.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_26.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_5.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_24.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_36.wav
#   inflating: /content/M214_project_data/train_clean/4_george_17.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_7.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_23.wav
#   inflating: /content/M214_project_data/train_clean/2_nicolas_33.wav
#   inflating: /content/M214_project_data/train_clean/0_yweweler_20.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_39.wav
#   inflating: /content/M214_project_data/train_clean/7_george_33.wav
#   inflating: /content/M214_project_data/train_clean/6_nicolas_46.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_12.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_48.wav
#   inflating: /content/M214_project_data/train_clean/2_george_9.wav
#   inflating: /content/M214_project_data/train_clean/8_nicolas_37.wav
#   inflating: /content/M214_project_data/train_clean/8_jackson_34.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_13.wav
#   inflating: /content/M214_project_data/train_clean/1_george_47.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_8.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_42.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_43.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_7.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_48.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_5.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_16.wav
#   inflating: /content/M214_project_data/train_clean/5_george_36.wav
#   inflating: /content/M214_project_data/train_clean/5_lucas_17.wav
#   inflating: /content/M214_project_data/train_clean/4_yweweler_19.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_27.wav
#   inflating: /content/M214_project_data/train_clean/6_nicolas_19.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_26.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_31.wav
#   inflating: /content/M214_project_data/train_clean/5_theo_44.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_7.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_22.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_43.wav
#   inflating: /content/M214_project_data/train_clean/0_george_8.wav
#   inflating: /content/M214_project_data/train_clean/4_lucas_34.wav
#   inflating: /content/M214_project_data/train_clean/1_jackson_21.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_25.wav
#   inflating: /content/M214_project_data/train_clean/7_george_30.wav
#   inflating: /content/M214_project_data/train_clean/2_nicolas_25.wav
#   inflating: /content/M214_project_data/train_clean/7_george_20.wav
#   inflating: /content/M214_project_data/train_clean/2_theo_26.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_28.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_18.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_17.wav
#   inflating: /content/M214_project_data/train_clean/6_lucas_22.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_24.wav
#   inflating: /content/M214_project_data/train_clean/9_george_21.wav
#   inflating: /content/M214_project_data/train_clean/5_george_31.wav
#   inflating: /content/M214_project_data/train_clean/2_nicolas_40.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_5.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_20.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_12.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_16.wav
#   inflating: /content/M214_project_data/train_clean/3_george_18.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_46.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_38.wav
#   inflating: /content/M214_project_data/train_clean/5_george_27.wav
#   inflating: /content/M214_project_data/train_clean/3_jackson_40.wav
#   inflating: /content/M214_project_data/train_clean/4_nicolas_45.wav
#   inflating: /content/M214_project_data/train_clean/9_nicolas_46.wav
#   inflating: /content/M214_project_data/train_clean/5_george_34.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_23.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_26.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_11.wav
#   inflating: /content/M214_project_data/train_clean/8_lucas_29.wav
#   inflating: /content/M214_project_data/train_clean/8_lucas_21.wav
#   inflating: /content/M214_project_data/train_clean/5_lucas_12.wav
#   inflating: /content/M214_project_data/train_clean/7_lucas_30.wav
#   inflating: /content/M214_project_data/train_clean/7_george_11.wav
#   inflating: /content/M214_project_data/train_clean/8_george_8.wav
#   inflating: /content/M214_project_data/train_clean/3_yweweler_43.wav
#   inflating: /content/M214_project_data/train_clean/7_george_39.wav
#   inflating: /content/M214_project_data/train_clean/1_theo_26.wav
#   inflating: /content/M214_project_data/train_clean/9_theo_33.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_15.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_22.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_49.wav
#   inflating: /content/M214_project_data/train_clean/8_george_35.wav
#   inflating: /content/M214_project_data/train_clean/7_jackson_5.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_19.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_26.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_9.wav
#   inflating: /content/M214_project_data/train_clean/8_theo_37.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_38.wav
#   inflating: /content/M214_project_data/train_clean/8_lucas_42.wav
#   inflating: /content/M214_project_data/train_clean/5_theo_5.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_45.wav
#   inflating: /content/M214_project_data/train_clean/4_jackson_9.wav
#   inflating: /content/M214_project_data/train_clean/5_lucas_24.wav
#   inflating: /content/M214_project_data/train_clean/5_george_42.wav
#   inflating: /content/M214_project_data/train_clean/6_lucas_34.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_24.wav
#   inflating: /content/M214_project_data/train_clean/1_lucas_11.wav
#   inflating: /content/M214_project_data/train_clean/6_theo_25.wav
#   inflating: /content/M214_project_data/train_clean/5_george_39.wav
#   inflating: /content/M214_project_data/train_clean/6_nicolas_32.wav
#   inflating: /content/M214_project_data/train_clean/7_yweweler_49.wav
#   inflating: /content/M214_project_data/train_clean/6_nicolas_23.wav
#   inflating: /content/M214_project_data/train_clean/4_nicolas_20.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_41.wav
#   inflating: /content/M214_project_data/train_clean/1_nicolas_47.wav
#   inflating: /content/M214_project_data/train_clean/3_yweweler_44.wav
#   inflating: /content/M214_project_data/train_clean/0_yweweler_29.wav
#   inflating: /content/M214_project_data/train_clean/1_theo_29.wav
#   inflating: /content/M214_project_data/train_clean/3_nicolas_26.wav
#   inflating: /content/M214_project_data/train_clean/9_george_32.wav
#   inflating: /content/M214_project_data/train_clean/3_yweweler_37.wav
#   inflating: /content/M214_project_data/train_clean/6_lucas_44.wav
#   inflating: /content/M214_project_data/train_clean/2_yweweler_22.wav
#   inflating: /content/M214_project_data/train_clean/4_theo_38.wav
#   inflating: /content/M214_project_data/train_clean/0_lucas_40.wav
#   inflating: /content/M214_project_data/train_clean/9_george_41.wav
#   inflating: /content/M214_project_data/train_clean/2_lucas_31.wav
#   inflating: /content/M214_project_data/train_clean/9_lucas_35.wav
#   inflating: /content/M214_project_data/train_clean/7_theo_24.wav
#   inflating: /content/M214_project_data/train_clean/2_jackson_13.wav
#   inflating: /content/M214_project_data/train_clean/3_yweweler_36.wav
#   inflating: /content/M214_project_data/train_clean/2_nicolas_41.wav
#   inflating: /content/M214_project_data/train_clean/9_yweweler_48.wav
#   inflating: /content/M214_project_data/train_clean/0_jackson_25.wav
#   inflating: /content/M214_project_data/train_clean/5_yweweler_42.wav
#   inflating: /content/M214_project_data/train_clean/1_yweweler_5.wav
#   inflating: /content/M214_project_data/train_clean/8_yweweler_29.wav
#   inflating: /content/M214_project_data/train_clean/0_nicolas_44.wav
#   inflating: /content/M214_project_data/train_clean/2_george_10.wav
#   inflating: /content/M214_project_data/train_clean/3_theo_15.wav
#   inflating: /content/M214_project_data/train_clean/1_yweweler_22.wav
#   inflating: /content/M214_project_data/train_clean/3_lucas_5.wav
# ...
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_nicolas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_george_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_jackson_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_nicolas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_jackson_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_nicolas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_yweweler_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_lucas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_yweweler_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_yweweler_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_lucas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_yweweler_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_nicolas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_lucas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_jackson_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_lucas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_jackson_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_george_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_jackson_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_yweweler_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_nicolas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_nicolas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_george_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_nicolas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_lucas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_jackson_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_george_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_jackson_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_george_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_theo_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_yweweler_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_lucas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_nicolas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_lucas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_jackson_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_yweweler_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_theo_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_george_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_lucas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_lucas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_lucas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_george_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_george_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_lucas_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_yweweler_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_yweweler_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_jackson_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_lucas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_jackson_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_yweweler_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_lucas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_yweweler_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_yweweler_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_yweweler_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/0_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_yweweler_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/4_nicolas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_george_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_yweweler_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_yweweler_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_nicolas_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_yweweler_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/3_nicolas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_nicolas_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_yweweler_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_george_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_george_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_jackson_0.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_george_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/5_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_yweweler_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/1_theo_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_george_3.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/8_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_jackson_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_theo_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/6_nicolas_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/9_theo_1.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_yweweler_4.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/2_lucas_2.wav
#   inflating: /content/M214_project_data/test_snr_10db_babble/7_jackson_1.wav

# %%
import os
import random
import numpy as np
import copy

# Set before CUDA ops for deterministic CUDA kernels.
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchaudio
import librosa
from glob import glob
import time

SEED = 0
#SEED = int(time.time())

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(SEED)

# %%
# ============================================================
# Dataset paths
# ============================================================
root_folder = "/content"
TRAIN_DIR       = root_folder + "/M214_project_data/train_clean"
TEST_CLEAN_DIR    = root_folder + "/M214_project_data/test_clean"
TEST_NOISY_5DB_DIR    = root_folder + "/M214_project_data/test_snr_5db_babble"
TEST_NOISY_10DB_DIR   = root_folder + "/M214_project_data/test_snr_10db_babble"

# ============================================================
# Audio loading
# ============================================================

def load_audio(audio_file):
    audio, fs = torchaudio.load(audio_file)
    audio = audio.numpy().reshape(-1)
    return audio, int(fs)

# %%
import librosa
import numpy as np
import scipy.ndimage
from scipy.signal import find_peaks

import librosa
import numpy as np
import scipy.ndimage
from scipy.signal import find_peaks

import librosa
import numpy as np
import scipy.ndimage

#final crop spectral subtraction
def spectral_subtraction_and_crop_with_peaks(audio, n_fft=512, hop_length=160, alpha=1.0, beta=0.05, noise_window_frames=15, delta_percentile=40):
    """
    Mathematically identical to the 'Best Performing' version.
    Anchors start at 0 and crops the trailing silence based on delta percentiles.
    """
    # 1. Frequency Domain Transform
    stft = librosa.stft(audio, n_fft=n_fft, hop_length=hop_length)
    magnitude, phase = librosa.magphase(stft)
    num_frames = magnitude.shape[1]

    if num_frames == 0:
        return audio, 0

    # 2. VAD Logic (Streamlined to match your best performing version)
    rms = librosa.feature.rms(y=audio, frame_length=n_fft, hop_length=hop_length)[0]

    # Apply 20th percentile floor
    rms_threshold = np.percentile(rms, 20)
    rms_floored = np.maximum(rms, rms_threshold)
    rms_smoothed = scipy.ndimage.gaussian_filter1d(rms_floored, sigma=3)

    # Calculate Absolute Delta
    delta = librosa.feature.delta(rms_smoothed, width=5)
    abs_delta = np.abs(delta)

    # Zero out edge artifacts (the "ledges")
    pad_frames = 5 // 2
    abs_delta[:pad_frames] = 0
    abs_delta[-pad_frames:] = 0

    # Thresholding
    delta_thresh = np.percentile(abs_delta, delta_percentile)
    active_frames = np.where(abs_delta > delta_thresh)[0]

    # Boundary Selection (Anchored Start)
    start_frame = 0
    if len(active_frames) > 0:
        end_frame = active_frames[-1]
    else:
        end_frame = num_frames - 1

    # Safety check
    if start_frame >= end_frame:
        end_frame = num_frames - 1

    # 4. Noise Estimation (Everything after the speech)
    noise_frames = np.arange(end_frame, num_frames)
    if len(noise_frames) < 3:
        noise_frames = np.arange(max(0, num_frames - noise_window_frames), num_frames)

    noise_profile = np.mean(magnitude[:, noise_frames], axis=1, keepdims=True)

    # 5. Spectral Subtraction & Reconstruction
    speech_magnitude = magnitude[:, start_frame:end_frame]
    speech_phase = phase[:, start_frame:end_frame]

    # Apply Noise Profile & Spectral Floor
    subtracted = speech_magnitude - (alpha * noise_profile)
    clean_magnitude = np.maximum(subtracted, beta * noise_profile)

    reconstructed_stft = clean_magnitude * speech_phase
    clean_audio_cropped = librosa.istft(reconstructed_stft, hop_length=hop_length)

    return clean_audio_cropped

def soft_floor(x, thresh, beta=2.0):
    return thresh + (1.0 / beta) * np.log1p(np.exp(beta * (x - thresh)))

def rasta_filter(signal):
    """
    RASTA bandpass filter (Hermansky & Morgan, 1994).
    Keeps modulation frequencies ~1-12 Hz (syllable rate).
    Suppresses stationary noise and fast transients.
    """
    numer = np.array([0.2, 0.1, 0, -0.1, -0.2])
    denom = np.array([1, -0.98])
    zi = scipy.signal.lfilter_zi(numer, denom)
    filtered, _ = scipy.signal.lfilter(numer, denom, signal, zi=zi * signal[0])
    return filtered

def compute_safe_delta(data, width=9, order=1):
    is_1d = data.ndim == 1
    if is_1d:
        data = np.atleast_2d(data)

    num_frames = data.shape[1]
    if num_frames < width:
        pad_amount = width - num_frames
        padded_data = np.pad(data, pad_width=((0, 0), (0, pad_amount)), mode='edge')
        delta = librosa.feature.delta(padded_data, width=width, order=order)
        out = delta[:, :num_frames]
    else:
        out = librosa.feature.delta(data, width=width, order=order)

    return out[0] if is_1d else out

def extract_feature(audio, fs):
    N_MFCC = 24
    WIN_LENGTH = 200
    HOP_LENGTH = 80
    N_FFT = 256

    # 1. Pre-emphasis
    audio = librosa.effects.preemphasis(audio, coef=0.97)

    # 2. Additive Noise Removal (Restored to standard levels)
    audio = spectral_subtraction_and_crop_with_peaks(
        audio, n_fft=N_FFT, hop_length=HOP_LENGTH,
        alpha=1.0, beta=0.05
    )

    # 3. Compute Base Mel-spectrogram & Log-Mel
    mels = librosa.feature.melspectrogram(
        y=audio, sr=fs, n_fft=N_FFT, hop_length=HOP_LENGTH,
        win_length=WIN_LENGTH, n_mels=N_MFCC, fmin=128, fmax=4000
    )
    mels_db1 = librosa.power_to_db(mels, ref=np.max)

    # ==========================================================
    # THE FIX: SVD LOW-RANK APPROXIMATION
    # ==========================================================
    # Calculate the Singular Value Decomposition of the matrix
    U, S, Vh = np.linalg.svd(mels_db1, full_matrices=False)

    # Keep only the top 12 components (Speech).
    # Dynamically scale k just in case a clip is abnormally short.
    k = min(5, mels_db1.shape[0], mels_db1.shape[1])

    # Zero out the bottom components (Noise) and reconstruct
    S_k = np.zeros_like(S)
    S_k[:k] = S[:k]
    mels_db_svd = U @ np.diag(S_k) @ Vh
    # 4. Apply Soft Floor to the newly purified matrix
    dynRange = 20
    mels_db_max = np.max(mels_db_svd)
    mels_db = soft_floor(mels_db_svd, mels_db_max - dynRange, 0.5)

    # 5. Unsharp Masking
    sigma = 0.6
    alpha_unsharp = 0.8
    blurred = scipy.ndimage.gaussian_filter(mels_db, sigma=sigma)
    mels_db_sharp = mels_db + alpha_unsharp * (mels_db - blurred)

    # --- TIER 1: STATIC FEATURES ---
    d0_mean, d0_std = np.mean(mels_db_sharp), np.std(mels_db_sharp) + 1e-6
    mels_base = (mels_db_sharp - d0_mean) / d0_std

    # --- TIER 2 & 3: DYNAMIC FEATURES ---
    mels_rasta = np.apply_along_axis(rasta_filter, 1, mels_db) # used to be mels_db_sharp

    mels_delta = compute_safe_delta(mels_rasta, width=9, order=1)
    d_mean, d_std = np.mean(mels_delta), np.std(mels_delta) + 1e-6
    mels_delta = (mels_delta - d_mean) / d_std

    mels_delta2 = compute_safe_delta(mels_rasta, width=9, order=2)
    d2_mean, d2_std = np.mean(mels_delta2), np.std(mels_delta2) + 1e-6
    mels_delta2 = (mels_delta2 - d2_mean) / d2_std

    # --- TIER 4: ROBUST ENERGY SHAPE ---
    robust_energy = np.mean(mels_rasta, axis=0)
    robust_delta = compute_safe_delta(robust_energy, width=9, order=1)

    r_mean, r_std = np.mean(robust_delta), np.std(robust_delta) + 1e-6
    robust_delta_norm = (robust_delta - r_mean) / r_std

    # Final Stacking
    features = np.vstack([mels_base, mels_delta, mels_delta2, robust_delta_norm])

    return features.astype(np.float32)

def extract_feature_from_file(audio_file):
    audio, fs = load_audio(audio_file)
    return extract_feature(audio, fs)

# %%
# ============================================================
# Dataset & DataLoader
# ============================================================

class FeatureDataset(torch.utils.data.Dataset):
    def __init__(self, X_list, y):
        self.X = X_list          # list of (F, T) np arrays
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = torch.from_numpy(self.X[idx])  # (F, T)
        return x, int(self.y[idx]), x.shape[1]


def collate_pad(batch):
    xs, ys, lens = zip(*batch)
    B = len(xs)
    F = xs[0].shape[0]
    T_max = max(lens)
    xb = torch.zeros(B, 1, F, T_max, dtype=xs[0].dtype)
    for i, x in enumerate(xs):
        xb[i, 0, :, :x.shape[1]] = x
    return xb, torch.tensor(ys, dtype=torch.long), torch.tensor(lens, dtype=torch.long)

# ============================================================
# Data loading
# ============================================================

def get_label(file_name):
    base = os.path.splitext(os.path.basename(file_name))[0]
    return int(base.split("_")[0])


def load_dir(data_dir, desc="Loading"):
    files = sorted(glob(os.path.join(data_dir, "*.wav")))
    if not files:
        print(f"No wav files found in {data_dir}")
        return [], []
    feats, labels = [], []
    for wav in files:
        feats.append(extract_feature_from_file(wav))
        labels.append(get_label(wav))
    print(f"  {desc}: {len(feats)} files loaded")
    return feats, labels

# %%
# ============================================================
# LSTM model
# ============================================================

class SimpleLSTM(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size, hidden_size=128, num_layers=2,
            batch_first=True, bidirectional=True,
            dropout=0.2
        )
        self.classifier = nn.Sequential(
            nn.Linear(256, 32), nn.ReLU(), nn.Dropout(0.3), nn.Linear(32, 10),
        )

    def forward(self, x, lengths):
        # x: (B,1,F,T) -> (B,T,F)
        x = x.squeeze(1).permute(0, 2, 1).contiguous()

        packed = nn.utils.rnn.pack_padded_sequence(
            x, lengths.cpu(), batch_first=True, enforce_sorted=False
        )
        out, _ = self.lstm(packed)
        out, _ = nn.utils.rnn.pad_packed_sequence(out, batch_first=True)  # (B, T_max, 256)

        # ---- mean pooling over valid frames (ignore padding) ----
        B, T_max, D = out.shape
        device = out.device

        # mask: (B, T_max), True for valid timesteps
        mask = torch.arange(T_max, device=device).unsqueeze(0) < lengths.unsqueeze(1)

        # expand mask to (B, T_max, D) and zero-out padding
        mask_f = mask.unsqueeze(-1).float()
        out_sum = (out * mask_f).sum(dim=1)                       # (B, D)
        denom = mask_f.sum(dim=1).clamp(min=1.0)                  # (B, 1)
        mean = out_sum / denom                                    # (B, D)

        return self.classifier(mean)

# %%
# ============================================================
# Evaluation
# ============================================================

import matplotlib.pyplot as plt
from sklearn import metrics

@torch.no_grad()
def evaluate(model, loader, device, plot_cm=False, class_names=None, title=None, save_path=None):
    """
    Returns:
      acc (float) by default.
      If plot_cm=True, also returns (acc, cm).
    """
    model.eval()
    if loader is None:
        return (0.0, None) if plot_cm else 0.0

    all_preds = []
    all_labels = []

    correct, total = 0, 0
    for xb, yb, lengths in loader:
        xb, yb, lengths = xb.to(device), yb.to(device), lengths.to(device)
        logits = model(xb, lengths)
        preds = logits.argmax(dim=1)

        correct += (preds == yb).sum().item()
        total += yb.size(0)

        if plot_cm:
            all_preds.append(preds.detach().cpu().numpy())
            all_labels.append(yb.detach().cpu().numpy())

    acc = correct / total if total > 0 else 0.0

    if not plot_cm:
        return acc

    y_pred = np.concatenate(all_preds) if all_preds else np.array([], dtype=np.int64)
    y_true = np.concatenate(all_labels) if all_labels else np.array([], dtype=np.int64)

    cm = metrics.confusion_matrix(y_true, y_pred, labels=None)

    # Plot
    disp = metrics.ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=class_names if class_names is not None else None
    )
    disp.plot(values_format="d")
    plt.title(title or "Confusion Matrix")
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=150)
        plt.close()
    else:
        plt.show()

    return acc, cm

# %%
# Training
BATCH_SIZE = 32
NUM_EPOCHS = 40
LR = 3e-4

# %%
# --- Load data ---
train_feat, train_label   = load_dir(TRAIN_DIR, desc="Train")
test_feat,  test_label    = load_dir(TEST_CLEAN_DIR, desc="Test clean")
noisy5_feat, noisy5_label = load_dir(TEST_NOISY_5DB_DIR, desc="Test noisy 5dB")
noisy10_feat, noisy10_label = load_dir(TEST_NOISY_10DB_DIR, desc="Test noisy 10dB")

feat_dim = train_feat[0].shape[0]
print(f"\nFeature dim: {feat_dim}")
print(f"Train: {len(train_feat)}  |  Test clean: {len(test_feat)}  "
      f"|  Test noisy 5dB: {len(noisy5_feat)}  |  Test noisy 10dB: {len(noisy10_feat)}")

for name, flist in [("Train", train_feat), ("Test clean", test_feat),
                    ("Noisy 5dB", noisy5_feat), ("Noisy 10dB", noisy10_feat)]:
    if flist:
        lengths = [f.shape[1] for f in flist]
        print(f"  {name:10s} frames: min={min(lengths)}, max={max(lengths)}, mean={np.mean(lengths):.1f}")

y_train   = np.array(train_label, dtype=np.int64)
y_test    = np.array(test_label,  dtype=np.int64)
y_noisy5  = np.array(noisy5_label, dtype=np.int64)
y_noisy10 = np.array(noisy10_label, dtype=np.int64)

# --- DataLoaders ---
loader_g = torch.Generator().manual_seed(SEED)

train_loader = DataLoader(
    FeatureDataset(train_feat, y_train),
    batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_pad, generator=loader_g,
)
test_loader = DataLoader(
    FeatureDataset(test_feat, y_test),
    batch_size=16, shuffle=False, collate_fn=collate_pad
)
noisy5_loader = None
if noisy5_feat:
    noisy5_loader = DataLoader(
        FeatureDataset(noisy5_feat, y_noisy5),
        batch_size=16, shuffle=False, collate_fn=collate_pad,
    )
noisy10_loader = None
if noisy10_feat:
    noisy10_loader = DataLoader(
        FeatureDataset(noisy10_feat, y_noisy10),
        batch_size=16, shuffle=False, collate_fn=collate_pad,
    )
# Out:
#   Train: 2500 files loaded
#   Test clean: 300 files loaded
#   Test noisy 5dB: 300 files loaded
#   Test noisy 10dB: 300 files loaded
#
# Feature dim: 73
# Train: 2500  |  Test clean: 300  |  Test noisy 5dB: 300  |  Test noisy 10dB: 300
#   Train      frames: min=11, max=226, mean=33.9
#   Test clean frames: min=12, max=112, mean=33.6
#   Noisy 5dB  frames: min=12, max=108, mean=33.8
#   Noisy 10dB frames: min=12, max=111, mean=33.6

# %%
# --- Training ---
set_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = SimpleLSTM(input_size=feat_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=LR)

best_clean, best_clean_ep = 0.0, -1
best_5db,  best_5db_ep  = 0.0, -1
best_10db, best_10db_ep = 0.0, -1

"""
Save the checkpoint with the best 10 dB accuracy.
You may instead choose to save the model with the best clean or 5 dB accuracy,
but keep in mind that your final score depends on strong performance on all of the test sets, especially the noisy test set.
"""
saved_checkpoint = None

from tqdm.notebook import tqdm

for epoch in tqdm(range(1, NUM_EPOCHS + 1), desc="Training"):
    net.train()
    total_loss = 0.0
    for xb, yb, lengths in train_loader:
        xb, yb, lengths = xb.to(device), yb.to(device), lengths.to(device)
        optimizer.zero_grad()
        loss = criterion(net(xb, lengths), yb)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(net.parameters(), 1.0)
        optimizer.step()
        total_loss += loss.item() * xb.size(0)

    avg_loss = total_loss / len(train_loader.dataset)
    clean_acc = evaluate(net, test_loader, device)
    acc_5db  = evaluate(net, noisy5_loader, device)
    acc_10db = evaluate(net, noisy10_loader, device)

    print(f"Epoch {epoch:02d}  loss={avg_loss:.4f}  "
          f"clean={clean_acc:.4f}  5dB={acc_5db:.4f}  10dB={acc_10db:.4f}")

    if clean_acc > best_clean:
        best_clean, best_clean_ep = clean_acc, epoch
    if acc_5db > best_5db:
        best_5db, best_5db_ep = acc_5db, epoch
        saved_checkpoint = copy.deepcopy(net.state_dict())  # save the best checkpoint
    if acc_10db > best_10db:
        best_10db, best_10db_ep = acc_10db, epoch
# Out:
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 01  loss=2.0565  clean=0.5267  5dB=0.4933  10dB=0.5300
# Epoch 02  loss=1.2212  clean=0.8800  5dB=0.8500  10dB=0.8567
# Epoch 03  loss=0.5833  clean=0.9333  5dB=0.9067  10dB=0.9300
# Epoch 04  loss=0.3354  clean=0.9367  5dB=0.9167  10dB=0.9333
# Epoch 05  loss=0.2140  clean=0.9800  5dB=0.9600  10dB=0.9667
# Epoch 06  loss=0.1544  clean=0.9867  5dB=0.9467  10dB=0.9633
# Epoch 07  loss=0.1231  clean=0.9733  5dB=0.9367  10dB=0.9667
# Epoch 08  loss=0.1069  clean=0.9800  5dB=0.9400  10dB=0.9633
# Epoch 09  loss=0.0656  clean=0.9800  5dB=0.9433  10dB=0.9800
# Epoch 10  loss=0.0697  clean=0.9733  5dB=0.9500  10dB=0.9733
# Epoch 11  loss=0.0634  clean=0.9767  5dB=0.9667  10dB=0.9833
# Epoch 12  loss=0.0425  clean=0.9733  5dB=0.9433  10dB=0.9667
# Epoch 13  loss=0.0347  clean=0.9767  5dB=0.9533  10dB=0.9800
# Epoch 14  loss=0.0313  clean=0.9900  5dB=0.9700  10dB=0.9900
# Epoch 15  loss=0.0339  clean=0.9867  5dB=0.9500  10dB=0.9800
# Epoch 16  loss=0.0332  clean=0.9800  5dB=0.9433  10dB=0.9733
# Epoch 17  loss=0.0217  clean=0.9800  5dB=0.9433  10dB=0.9700
# Epoch 18  loss=0.0226  clean=0.9900  5dB=0.9667  10dB=0.9833
# Epoch 19  loss=0.0224  clean=0.9767  5dB=0.9567  10dB=0.9733
# Epoch 20  loss=0.0209  clean=0.9833  5dB=0.9467  10dB=0.9633
# Epoch 21  loss=0.0174  clean=0.9733  5dB=0.9367  10dB=0.9800
# Epoch 22  loss=0.0151  clean=0.9833  5dB=0.9567  10dB=0.9833
# Epoch 23  loss=0.0235  clean=0.9800  5dB=0.9633  10dB=0.9733
# Epoch 24  loss=0.0248  clean=0.9833  5dB=0.9633  10dB=0.9833
# Epoch 25  loss=0.0170  clean=0.9800  5dB=0.9667  10dB=0.9767
# Epoch 26  loss=0.0110  clean=0.9800  5dB=0.9600  10dB=0.9833
# Epoch 27  loss=0.0163  clean=0.9833  5dB=0.9667  10dB=0.9767
# Epoch 28  loss=0.0214  clean=0.9833  5dB=0.9700  10dB=0.9700
# Epoch 29  loss=0.0243  clean=0.9700  5dB=0.9300  10dB=0.9567
# Epoch 30  loss=0.0262  clean=0.9767  5dB=0.9600  10dB=0.9733
# Epoch 31  loss=0.0646  clean=0.9800  5dB=0.9233  10dB=0.9633
# Epoch 32  loss=0.0400  clean=0.9900  5dB=0.9567  10dB=0.9733
# Epoch 33  loss=0.0183  clean=0.9833  5dB=0.9667  10dB=0.9833
# Epoch 34  loss=0.0208  clean=0.9833  5dB=0.9633  10dB=0.9767
# Epoch 35  loss=0.0207  clean=0.9900  5dB=0.9700  10dB=0.9933
# Epoch 36  loss=0.0144  clean=0.9867  5dB=0.9400  10dB=0.9700
# Epoch 37  loss=0.0239  clean=0.9867  5dB=0.9533  10dB=0.9900
# Epoch 38  loss=0.0117  clean=0.9767  5dB=0.9400  10dB=0.9633
# Epoch 39  loss=0.0119  clean=0.9900  5dB=0.9700  10dB=0.9833
# Epoch 40  loss=0.0083  clean=0.9900  5dB=0.9733  10dB=0.9867

# %%
# load the best checkpoint before testing
net = SimpleLSTM(input_size=feat_dim).to(device)
net.load_state_dict(saved_checkpoint)
# clean_acc = evaluate(net, test_loader, device)
clean_acc, cm_clean = evaluate(
    net, test_loader, device,
    plot_cm=True,
    class_names=list(range(10)),
    title="Confusion Matrix — Clean"
)
acc_5db, cm_5db = evaluate(
    net, noisy5_loader, device,
    plot_cm=True,
    class_names=list(range(10)),
    title="Confusion Matrix — Noisy 5 dB"
)
acc_10db, cm_10db = evaluate(
    net, noisy10_loader, device,
    plot_cm=True,
    class_names=list(range(10)),
    title="Confusion Matrix — Noisy 10 dB"
)
print(f"\nBest checkpoint loaded (epoch {best_5db_ep})")
print(f"Clean accuracy : {clean_acc:.4f}")
print(f"5dB accuracy   : {acc_5db:.4f}")
print(f"10dB accuracy  : {acc_10db:.4f}")
# Out:
# Best checkpoint loaded (epoch 40)
# Clean accuracy : 0.9900
# 5dB accuracy   : 0.9733
# 10dB accuracy  : 0.9867
